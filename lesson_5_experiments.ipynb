# %%
print("Привет, JupyterLab!")
# Out:
# Привет, JupyterLab!

# %%
import numpy as np

# Замеряем скорость обычного Python (цикл и list comprehension)
# %timeit [i**2 for i in range(100000)]

# Замеряем скорость NumPy (векторизация)
# %timeit np.arange(100000)**2
# Out:
# 7.95 ms ± 632 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# 150 μs ± 5.67 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %pip install numpy
# Out:
# ...
#   Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Using cached numpy-2.4.6-cp314-cp314-win_amd64.whl (12.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
