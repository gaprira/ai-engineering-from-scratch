# %%
x = 10
print(f"Шаг 1: x равен {x}")
# Out:
# Шаг 1: x равен 100

# %%
y = 20
print(f"Шаг 2: y равен {y}")
# Out:
# Шаг 2: y равен 20

# %%
result = x + y
print(f"Итог: {result}")
# Out:
# Итог: 120
